# %%
# !pip install flask_ngrok

# %%
# !pip install pymongo[srv]

# %%
# from flask_ngrok import run_with_ngrok
from flask import Flask
from flask import request
from flask import jsonify
from pymongo import MongoClient

app = Flask(__name__)
# run_with_ngrok(app)
@app.route('/')
def home():
  return '<h1>Hello from Flask</h1>'

# @app.route('/greeting')
# def greeting():
#   name=request.args.get('name')
#   return '<h3>Hello '+name+'</h3>'

@app.route('/insertscore')
def insertscore():
  # id=request.args.get('id')
  # q1=request.args.get('q1')
  # q2=request.args.get('q2')
  # q3=request.args.get('q3')
  # q4=request.args.get('q4')
  # q5=request.args.get('q5')
  line=request.args.get('score')
  id,q1,q2,q3,q4,q5 = line.split(',')
  sum=(int(q1)+int(q2)+int(q3)+int(q4)+int(q5))
  client=MongoClient("mongodb+srv://testuser:beam4456@cluster0.ntixl.mongodb.net/Demo1?retryWrites=true&w=majority")
  db=client.all_scores
  db.score.insert_one({'id':id,'q1':int(q1),'q2':int(q2),'q3':int(q3),'q4':int(q4),'q5':int(q5),'sum':sum})
  return '<h3>Finished</h3>'

# @app.route('/get'
# def get():
#   ret=dict()
#   ret['data']=[{'id':'6238212021','q1':8,'q2':9},{'id':'6231111111','q1':7,'q2':6}]
#   return jsonify(ret)
# app.run()

import threading
threading.Thread(target=app.run, kwargs={'host':'0.0.0.0','port':80}).start()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://0.0.0.0:80/ (Press CTRL+C to quit)

# %%
import requests
file = open('score.csv')

for line in file:
  r=requests.get("http://172.28.0.2/insertscore?score="+line)
  print(r.text)
# Out:
# 172.28.0.2 - - [22/Oct/2020 03:59:02] "GET /insertscore?score=5963032021,10,2,8,9,10%0A HTTP/1.1" 200 -
# <h3>Finished</h3>
# 172.28.0.2 - - [22/Oct/2020 03:59:04] "GET /insertscore?score=5920552721,1,1,2,0,9%0A HTTP/1.1" 200 -
# <h3>Finished</h3>
# 172.28.0.2 - - [22/Oct/2020 03:59:06] "GET /insertscore?score=5995635821,8,8,6,10,7%0A HTTP/1.1" 200 -
# <h3>Finished</h3>
# 172.28.0.2 - - [22/Oct/2020 03:59:08] "GET /insertscore?score=5941861521,7,1,8,4,8%0A HTTP/1.1" 200 -
# <h3>Finished</h3>
# 172.28.0.2 - - [22/Oct/2020 03:59:10] "GET /insertscore?score=5950684221,1,4,7,2,9%0A HTTP/1.1" 200 -
# <h3>Finished</h3>
# 172.28.0.2 - - [22/Oct/2020 03:59:11] "GET /insertscore?score=5934246121,4,10,7,10,4%0A HTTP/1.1" 200 -
# <h3>Finished</h3>
# 172.28.0.2 - - [22/Oct/2020 03:59:13] "GET /insertscore?score=5921260421,7,0,3,10,1%0A HTTP/1.1" 200 -
# <h3>Finished</h3>
# 172.28.0.2 - - [22/Oct/2020 03:59:15] "GET /insertscore?score=5956968821,6,1,3,2,5%0A HTTP/1.1" 200 -
# <h3>Finished</h3>
# ...

# %% [markdown]
# #PART 2

# %%
# from flask_ngrok import run_with_ngrok
from flask import Flask
from flask import request
from flask import jsonify
from pymongo import MongoClient

app = Flask(__name__)
# run_with_ngrok(app)
@app.route('/')
def home():
  return '<h1>Hello from Flask</h1>'

# @app.route('/greeting')
# def greeting():
#   name=request.args.get('name')
#   return '<h3>Hello '+name+'</h3>'

@app.route('/findscore')
def findscore():
  id=request.args.get('id')
  client=MongoClient("mongodb+srv://testuser:beam4456@cluster0.ntixl.mongodb.net/Demo1?retryWrites=true&w=majority")
  documents=client.all_scores['score']
  doc=documents.find({'id':id})
  ret=dict()
  for docs in doc:
    ret['data']={'id':docs['id'],'q1':docs['q1'],'q2':docs['q2'],'q3':docs['q3'],'q4':docs['q4'],'q5':docs['q5'],'sum':docs['sum']}
  return jsonify(ret)

@app.route('/insertscore')
def insertscore():
  # id=request.args.get('id')
  # q1=request.args.get('q1')
  # q2=request.args.get('q2')
  # q3=request.args.get('q3')
  # q4=request.args.get('q4')
  # q5=request.args.get('q5')
  line=request.args.get('score')
  id,q1,q2,q3,q4,q5 = line.split(',')
  sum=(int(q1)+int(q2)+int(q3)+int(q4)+int(q5))
  client=MongoClient("mongodb+srv://testuser:beam4456@cluster0.ntixl.mongodb.net/Demo1?retryWrites=true&w=majority")
  db=client.all_scores
  db.score.insert_one({'id':id,'q1':int(q1),'q2':int(q2),'q3':int(q3),'q4':int(q4),'q5':int(q5),'sum':sum})
  return '<h3>Finished</h3>'

# @app.route('/get'
# def get():
#   ret=dict()
#   ret['data']=[{'id':'6238212021','q1':8,'q2':9},{'id':'6231111111','q1':7,'q2':6}]
#   return jsonify(ret)
# app.run()

import threading
threading.Thread(target=app.run, kwargs={'host':'0.0.0.0','port':80}).start()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://0.0.0.0:80/ (Press CTRL+C to quit)

# %%
import requests

r=requests.get("http://172.28.0.2/findscore?id=5920552721")
print(r.text)
# Out:
# 172.28.0.2 - - [22/Oct/2020 05:07:54] "GET /findscore?id=5920552721 HTTP/1.1" 200 -
# {"data":{"id":"5920552721","q1":1,"q2":1,"q3":2,"q4":0,"q5":9,"sum":13}}
