# %%
! pip install pymongo[srv]
# Out:
# ...
#      |████████████████████████████████| 194kB 4.9MB/s
# ...

# %%
! pip install dnspython

# %%
import pymongo
client = pymongo.MongoClient("mongodb+srv://testuser:beam4456@cluster0.ntixl.mongodb.net/Demo1?retryWrites=true&w=majority")
db = client.test

# %%
client.list_database_names()
# Out:
# ['all_score',
#  'all_scores',
#  'blog',
#  'landmarks_db',
#  'sample_airbnb',
#  'sample_analytics',
#  'sample_geospatial',
#  'sample_mflix',
#  'sample_restaurants',
#  'sample_supplies',
#  'sample_training',
#  'sample_weatherdata',
#  'student_scores',
#  'admin',
#  'local']

# %%
db = client.landmarks_db
db.list_collection_names()
# Out:
# ['landmarks']

# %%
documents=db['landmarks']

# %%
document=documents.find_one({})

# %%
# blog_post1 = {'author':'beam',
#              'text':'python is so powerful',
#              'tag':['python','programming language','hello world']}
# blog_post2 = {'author':'beam',
#              'text':'mongodb is so powerful',
#              'remark': 'mongodb is noSQL',
#              'tag':['mongodb','python','programming language','hello world']}
# blog_post3 = {'author':'beam',
#              'text':'pandas is so powerful',
#              'tag':['pandas','python','programming language','hello world']}

landmark1 = {'name': 'test_name',
             'desc': 'test_desc',
             'ratings': '10',
             'prange': '$99',
             'tags': ['restaurant','indoor','shopping','picturesque']}
landmark2 = {'name': 'test_name2',
             'desc': 'test_desc2',
             'ratings': '100',
             'prange': '$999',
             'tags': ['landmark','outdoor','sight-seeing','entertainment','picturesque']}

# %%
documents.insert_one(landmark2)

# %%
document.keys()
# Out:
# dict_keys(['_id', 'name', 'desc', 'ratings', 'prange', 'tags'])

# %%
# Out:
# Collection(Database(MongoClient(host=['cluster0-shard-00-00.ntixl.mongodb.net:27017', 'cluster0-shard-00-01.ntixl.mongodb.net:27017', 'cluster0-shard-00-02.ntixl.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-nisbfs-shard-0', ssl=True), 'landmarks_db'), 'landmarks')

# %%
print(document['name'])
print(document['address']['country'])
print(document['description'])
for review in document['reviews']:
  print('===================================')
  print(review['reviewer_name'])
  print(review['comments'])

# %%
document2=documents.find({})

# %%
type(document2)
# Out:
# pymongo.cursor.Cursor

# %%
countries = []
for doc in document2:
  # print(doc['name'])
  # print(doc['address']['country'])
  # print('===============')
  countries.append(doc['address']['country'])

# %%
from collections import Counter
Counter(countries).most_common(10)
# Out:
# [('United States', 1222),
#  ('Turkey', 661),
#  ('Canada', 649),
#  ('Spain', 633),
#  ('Australia', 610),
#  ('Brazil', 606),
#  ('Hong Kong', 600),
#  ('Portugal', 555),
#  ('China', 19)]

# %%
len(countries)
# Out:
# 5555

# %%
document3=documents.find({'address.country':'Spain'})
for doc in document3:
  print('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
  print(doc['name'])
  print(doc['address']['country'])

# %%
blog_post1 = {'author':'beam',
             'text':'python is so powerful',
             'tag':['python','programming language','hello world']}
blog_post2 = {'author':'beam',
             'text':'mongodb is so powerful',
             'remark': 'mongodb is noSQL',
             'tag':['mongodb','python','programming language','hello world']}
blog_post3 = {'author':'beam',
             'text':'pandas is so powerful',
             'tag':['pandas','python','programming language','hello world']}

# %%
blog_db = client.blog
blog_db.blogs.insert_one(blog_post1)

# %%
blog_db.blogs.insert_one(blog_post2)
blog_db.blogs.insert_one(blog_post3)
