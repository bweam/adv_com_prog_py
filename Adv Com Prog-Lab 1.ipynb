# %% [markdown]
# # Lab 1-Google Colab

# %%
print('Hello World')
print("Bye Java")
print("Hello Python")
print('10+500 = 510')
# Out:
# Hello World
# Bye Java
# Hello Python
# 10+500 = 510

# %% [markdown]
# ![Capture.PNG](data:image/png;base64,...)
