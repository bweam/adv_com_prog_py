# %% [markdown]
# # Problem 1

# %%
import seaborn as sbs
import pandas as pd

df=pd.read_csv('Iris.csv')

# %%
df
# Out:
#       Id  SepalLengthCm  ...  PetalWidthCm         Species
# 0      1            5.1  ...           0.2     Iris-setosa
# 1      2            4.9  ...           0.2     Iris-setosa
# 2      3            4.7  ...           0.2     Iris-setosa
# 3      4            4.6  ...           0.2     Iris-setosa
# 4      5            5.0  ...           0.2     Iris-setosa
# ..   ...            ...  ...           ...             ...
# 145  146            6.7  ...           2.3  Iris-virginica
# 146  147            6.3  ...           1.9  Iris-virginica
# 147  148            6.5  ...           2.0  Iris-virginica
# 148  149            6.2  ...           2.3  Iris-virginica
# 149  150            5.9  ...           1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %%
# sbs.pairplot(df,palette={'Iris-setosa':'blue','Iris-versicolor':'orange','Iris-virginica':'green'},y_vars='SepalLengthCm')

# %%
df=df.drop(columns='Id')

# %%
sbs.pairplot(df, hue='Species')

# %% [markdown]
# If you want to select the columns of the data that can be used
# to classify the Species of each flower, which variable(s) you will
# choose?

# %% [markdown]
# 'SepalLengthCm','PetalLengthCm','PetalWidthCm','Species'

# %% [markdown]
# # Problem 2

# %%
def get_color(x):
  if x >= 50:
    return 'red'
  elif x >= 37:
    return 'yellow'
  return 'green'

pm_df=pd.read_csv('pm25.csv')
pm_df.columns=['dt','pm']
pm_df=pm_df[pm_df['pm'] != '-']
pm_df['pm']=pd.to_numeric(pm_df['pm'])
pm_df['dt']=pd.to_datetime(pm_df['dt'])
pm_df['hr']=pm_df['dt'].dt.hour

colors = [get_color(x) for x in list(pm_df.groupby('hr').mean()['pm'])]

sbs.barplot(data=pm_df,x='hr',y='pm',palette=colors)

# %% [markdown]
# # Problem 3

# %%
hp_df = pd.read_csv('happiness.csv') #world happiness

# %%
hp_df
# Out:
#      Overall rank  ... Perceptions of corruption
# 0               1  ...                     0.393
# 1               2  ...                     0.410
# 2               3  ...                     0.341
# 3               4  ...                     0.118
# 4               5  ...                     0.298
# ..            ...  ...                       ...
# 151           152  ...                     0.411
# 152           153  ...                     0.147
# 153           154  ...                     0.025
# 154           155  ...                     0.035
# 155           156  ...                     0.091
#
# [156 rows x 9 columns]

# %%
hp_df.rename(columns={'Score':'Happiness'},inplace=True)

# %% [markdown]
# World Happiness ranking

# %%
import matplotlib.pyplot as plt

def get_color2(x):
  if x >= 7:
    return 'green'
  if x >= 6:
    return 'yellow'
  if x >= 5:
    return 'orange'
  if x >= 4:
    return 'red'
  return 'black'

colors2 = [get_color2(x) for x in hp_df['Happiness']]
fig,ax=plt.subplots(figsize=(24,8))
chart=sbs.barplot(x='Country or region', y='Happiness',data=hp_df,palette=colors2)
chart.set_xticklabels(chart.get_xticklabels(),rotation=90)
# Out:
# [Text(0, 0, 'Finland'),
#  Text(0, 0, 'Denmark'),
#  Text(0, 0, 'Norway'),
#  Text(0, 0, 'Iceland'),
#  Text(0, 0, 'Netherlands'),
#  Text(0, 0, 'Switzerland'),
#  Text(0, 0, 'Sweden'),
#  Text(0, 0, 'New Zealand'),
#  Text(0, 0, 'Canada'),
#  Text(0, 0, 'Austria'),
#  Text(0, 0, 'Australia'),
#  Text(0, 0, 'Costa Rica'),
#  Text(0, 0, 'Israel'),
#  Text(0, 0, 'Luxembourg'),
#  Text(0, 0, 'United Kingdom'),
#  Text(0, 0, 'Ireland'),
#  Text(0, 0, 'Germany'),
#  Text(0, 0, 'Belgium'),
#  Text(0, 0, 'United States'),
#  Text(0, 0, 'Czech Republic'),
#  Text(0, 0, 'United Arab Emirates'),
#  Text(0, 0, 'Malta'),
#  Text(0, 0, 'Mexico'),
#  Text(0, 0, 'France'),
#  Text(0, 0, 'Taiwan'),
#  Text(0, 0, 'Chile'),
#  Text(0, 0, 'Guatemala'),
#  Text(0, 0, 'Saudi Arabia'),
#  Text(0, 0, 'Qatar'),
#  Text(0, 0, 'Spain'),
#  Text(0, 0, 'Panama'),
#  Text(0, 0, 'Brazil'),
#  Text(0, 0, 'Uruguay'),
#  Text(0, 0, 'Singapore'),
#  Text(0, 0, 'El Salvador'),
#  Text(0, 0, 'Italy'),
# ...

# %% [markdown]
# Does people's perceptions of corruption correlates to people's level of happiness

# %%
import plotly.express as px

fig=px.scatter(hp_df,x='Perceptions of corruption',y='Happiness',color='Country or region')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="10f25850-b12a-4929-ba6f-8ccd3a2204a7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("10f25850-b12a-4929-ba6f-8ccd3a2204a7")) {
#                     Plotly.newPlot(
#                         '10f25850-b12a-4929-ba6f-8ccd3a2204a7',
# ...
