# %%
import pandas as pd

df = pd.read_json("contacts.json")
df.to_csv()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
df
# Out:
#             Id                Email  ... Contacts                    OrderId
# 0            0       gkzAbIy@qq.com  ...        1
# 1            1                       ...        4  vDDJJcxfLtSfkooPhbYnJdxov
# 2            2                       ...        0
# 3            3   mdllpYmE@gmail.com  ...        0  bHquEnCbbsGLqllwryxPsNOxa
# 4            4                       ...        2
# ...        ...                  ...  ...      ...                        ...
# 499995  499995                       ...        2  whJlUOGNqjxCRzmIRdURQvlNv
# 499996  499996                       ...        4  JqIXOONvrwvJxZqNxCYHqnrKS
# 499997  499997                       ...        2  beXCZSzcHaBwAYoDcpQqjuAFO
# 499998  499998  RzSDsyH@hotmail.com  ...        1  ehjeFACGiwrERQxbziMxwOWku
# 499999  499999                       ...        0  JibSBRgzYdfzkzbTuGUXrcvDX
#
# [500000 rows x 5 columns]

# %%
class Value:
    def __init__(self, v=None):
        self.v = v

v1 = Value(1)
v2 = Value(2)

contact = {'a': v1, 'b': v1, 'c': v2, 'd': v2}
contact['a'].v += 1
contact['e'] = 2
contact['b'].v == 2 # True
# Out:
# {'a': <__main__.Value at 0x7f475a87ddd0>,
#  'b': <__main__.Value at 0x7f475a87ddd0>,
#  'c': <__main__.Value at 0x7f475a81af90>,
#  'd': <__main__.Value at 0x7f475a81af90>,
#  'e': 2}

# %%
df['Email'][0]
# Out:
# 'gkzAbIy@qq.com'

# %%
groupEmail = df.groupby(['Email']).first()
groupEmail
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-94-29c3a8aa0722> in <module>()
# ----> 1 groupEmail = df.groupby(['Email'],['Id']).first()
#       2 groupEmail
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6511         if level is None and by is None:
#    6512             raise TypeError("You have to supply one of 'by' and 'level'")
# -> 6513         axis = self._get_axis_number(axis)
#    6514
#    6515         return DataFrameGroupBy(
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     366     def _get_axis_number(cls, axis: Axis) -> int:
#     367         try:
# --> 368             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     369         except KeyError:
# ...

# %%
groupEmailPhone = groupEmail.groupby(['Phone']).first()
groupEmailPhoneOrderId = groupEmailPhone.groupby(['OrderId']).first()
groupEmailPhoneOrderId.sort_values(['Id'])
sorted_group = groupEmailPhoneOrderId.groupby(['Id']).first()
sorted_group
# Out:
#         Contacts
# Id
# 1              4
# 13             1
# 17             3
# 22             0
# 28             1
# ...          ...
# 499806         3
# 499882         0
# 499973         1
# 499980         3
# 499998         1
#
# [24447 rows x 1 columns]

# %%
df
# Out:
#             Id                Email  ... Contacts                    OrderId
# 0            0       gkzAbIy@qq.com  ...        1
# 1            1                       ...        4  vDDJJcxfLtSfkooPhbYnJdxov
# 2            2                       ...        0
# 3            3   mdllpYmE@gmail.com  ...        0  bHquEnCbbsGLqllwryxPsNOxa
# 4            4                       ...        2
# ...        ...                  ...  ...      ...                        ...
# 499995  499995                       ...        2  whJlUOGNqjxCRzmIRdURQvlNv
# 499996  499996                       ...        4  JqIXOONvrwvJxZqNxCYHqnrKS
# 499997  499997                       ...        2  beXCZSzcHaBwAYoDcpQqjuAFO
# 499998  499998  RzSDsyH@hotmail.com  ...        1  ehjeFACGiwrERQxbziMxwOWku
# 499999  499999                       ...        0  JibSBRgzYdfzkzbTuGUXrcvDX
#
# [500000 rows x 5 columns]

# %%
class Value:
    def __init__(self, v=None):
        self.v = v

class Contact:
    def __init__(self, Id, Email, Phone, OrderId):
        self.Id = Id
        self.Email = Email
        self.Phone = Phone
        self.OrderId = OrderId
    
    def hasContact(self, Email, Phone, OrderId):
        return Email in self.Email or Phone in self.Phone or OrderId in self.OrderId

    def add(self, Id, Email, Phone, OrderId):
        self.Id.append(Id)
        self.Email.append(Email)
        self.Phone.append(Phone)
        self.OrderId.append(OrderId)
          

v = [None for i in range(0,500000)]
d = {'': 0}
for n, i in enumerate(df['Id']):
  if n == 3000:
    break
  if (df['Email'][i] != '' and df['Email'][i] not in d) ^ (df['Phone'][i] != '' and df['Phone'][i] not in d ) ^ (df['OrderId'][i] != '' and df['OrderId'][i] not in d): 
    v[i] = Value(1)
    d[df['Email'][i]] = v[i]
    d[df['Phone'][i]] = v[i]
    d[df['OrderId'][i]] = v[i]
  else:
    print("hi its beam")
    d[df['Email'][i]].v += 1
    d[df['Phone'][i]].v += 1
    d[df['OrderId'][i]].v += 1
  # if not Contact.hasContact(df['Email'][i], df['Phone'][i], df['OrderId'][i]):
  #   Contact(df['Id'][i], df['Email'][i], df['Phone'][i], df['OrderId'][i])
  
  # else:
  #   Contact.add(df['Id'][i], df['Email'][i], df['Phone'][i], df['OrderId'][i])

  # v.append(Contact)


d
# Out:
# hi its beam
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-96-7077bb562b15> in <module>()
#      33     print("hi its beam")
#      34     d[df['Email'][i]].v += 1
# ---> 35     d[df['Phone'][i]].v += 1
#      36     d[df['OrderId'][i]].v += 1
#      37   # if not Contact.hasContact(df['Email'][i], df['Phone'][i], df['OrderId'][i]):
#
# KeyError: '329442681752'
